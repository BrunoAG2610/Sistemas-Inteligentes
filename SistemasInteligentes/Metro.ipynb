# %%
# Clase abstracta
class Problem:
    def __init__(self, initial, goal):
        self.initial = initial # Estado inicial
        self.goal = goal # Meta
    
    def actions(self, state):
        raise NotImplementedError

    # Función de transición
    def result(self, state, action):
        raise NotImplementedError

    # Función de desempeño
    def is_goal(self, state):
        return self.goal == state
    
    def action_cost(self, state1, action, state2):
        return 1
   
    def h(self, state):
        return 0

# %%
class GraphProblem(Problem):
    def __init__(self, initial, goal, graph):
        super().__init__(initial, goal)
        self.graph = graph
    
    def actions(self, state):
        lista = []
        for key in self.graph[state].keys():
            lista.append(key)
        return lista

    # Función de transición
    def result(self, state, action):
        return action

    def action_cost(self, state1, action, state2):
        return self.graph[state1][state2]

# %%
metro_cdmx = {
    # --- LÍNEA 1 
    'Observatorio': {'Tacubaya': 2},
    'Tacubaya': {'Observatorio': 2, 'Juanacatlán': 2, 'Constituyentes': 2, 'San Pedro de los Pinos': 2, 'Auditorio': 2, 'Patriotismo': 2},
    'Juanacatlán': {'Tacubaya': 2, 'Chapultepec': 2},
    'Chapultepec': {'Juanacatlán': 2, 'Sevilla': 2},
    'Sevilla': {'Chapultepec': 2, 'Insurgentes': 2},
    'Insurgentes': {'Sevilla': 2, 'Cuauhtémoc': 2},
    'Cuauhtémoc': {'Insurgentes': 2, 'Balderas': 2},
    'Balderas': {'Cuauhtémoc': 2, 'Salto del Agua': 2, 'Juárez': 2, 'Niños Héroes': 2}, 
    'Salto del Agua': {'Balderas': 2, 'Isabel la Católica': 2, 'Doctores': 2, 'San Juan de Letrán': 2}, 
    'Isabel la Católica': {'Salto del Agua': 2, 'Pino Suárez': 2},
    'Pino Suárez': {'Isabel la Católica': 2, 'Merced': 2, 'Zócalo/Tenochtitlan': 2, 'San Antonio Abad': 2}, 
    'Merced': {'Pino Suárez': 2, 'Candelaria': 2},
    'Candelaria': {'Merced': 2, 'San Lázaro': 2, 'Fray Servando': 2, 'Jamaica': 2, 'Morelos': 2}, 
    'San Lázaro': {'Candelaria': 2, 'Moctezuma': 2, 'Ricardo Flores Magón': 2, 'Morelos': 2}, 
    'Moctezuma': {'San Lázaro': 2, 'Balbuena': 2},
    'Balbuena': {'Moctezuma': 2, 'Boulevard Puerto Aéreo': 2},
    'Boulevard Puerto Aéreo': {'Balbuena': 2, 'Gómez Farías': 2},
    'Gómez Farías': {'Boulevard Puerto Aéreo': 2, 'Zaragoza': 2},
    'Zaragoza': {'Gómez Farías': 2, 'Pantitlán': 3},
    'Pantitlán': {'Zaragoza': 3, 'Hangares': 2, 'Puebla': 2, 'Agrícola Oriental': 2},

    # --- LÍNEA 2 
    'Cuatro Caminos': {'Panteones': 3},
    'Panteones': {'Cuatro Caminos': 3, 'Tacuba': 2},
    'Tacuba': {'Panteones': 2, 'Cuitláhuac': 2, 'San Joaquín': 2, 'Refinería': 2},
    'Cuitláhuac': {'Tacuba': 2, 'Popotla': 2},
    'Popotla': {'Cuitláhuac': 2, 'Colegio Militar': 2},
    'Colegio Militar': {'Popotla': 2, 'Normal': 2},
    'Normal': {'Colegio Militar': 2, 'San Cosme': 2},
    'San Cosme': {'Normal': 2, 'Revolución': 2},
    'Revolución': {'San Cosme': 2, 'Hidalgo': 2},
    'Hidalgo': {'Revolución': 2, 'Bellas Artes': 2, 'Guerrero': 2, 'Juárez': 2},
    'Bellas Artes': {'Hidalgo': 2, 'Allende': 2, 'San Juan de Letrán': 2, 'Garibaldi': 2},
    'Allende': {'Bellas Artes': 2, 'Zócalo/Tenochtitlan': 2},
    'Zócalo/Tenochtitlan': {'Allende': 2, 'Pino Suárez': 2},
    'San Antonio Abad': {'Pino Suárez': 2, 'Chabacano': 2},
    'Chabacano': {'San Antonio Abad': 2, 'Viaducto': 2, 'Viga': 2, 'Lázaro Cárdenas': 2, 'Santa Anita': 2, 'Obrera': 2, 'Jamaica': 2},
    'Viaducto': {'Chabacano': 2, 'Xola': 2},
    'Xola': {'Viaducto': 2, 'Villa de Cortés': 2},
    'Villa de Cortés': {'Xola': 2, 'Nativitas': 2},
    'Nativitas': {'Villa de Cortés': 2, 'Portales': 2},
    'Portales': {'Nativitas': 2, 'General Anaya': 2},
    'Ermita': {'Portales': 2, 'General Anaya': 2, 'Mexicaltzingo': 2, 'Atlalilco': 2},
    'General Anaya': {'Portales': 2, 'Taxqueña': 3},
    'Taxqueña': {'General Anaya': 3},

    # --- LÍNEA 3 
    'Indios Verdes': {'Deportivo 18 de Marzo': 3},
    'Deportivo 18 de Marzo': {'Indios Verdes': 3, 'Potrero': 2, 'La Villa-Basílica': 2, 'Lindavista': 2},
    'Potrero': {'Deportivo 18 de Marzo': 2, 'La Raza': 2},
    'La Raza': {'Potrero': 2, 'Tlatelolco': 2, 'Autobuses del Norte': 2, 'Misterios': 2}, 
    'Tlatelolco': {'La Raza': 2, 'Guerrero': 2},
    'Guerrero': {'Tlatelolco': 2, 'Hidalgo': 2, 'Garibaldi': 2, 'Buenavista': 2}, 
    'Juárez': {'Hidalgo': 2, 'Balderas': 2},
    'Niños Héroes': {'Balderas': 2, 'Hospital General': 2},
    'Hospital General': {'Niños Héroes': 2, 'Centro Médico': 2},
    'Centro Médico': {'Hospital General': 2, 'Etiopía/Plaza de la Transparencia': 2, 'Chilpancingo': 2, 'Lázaro Cárdenas': 2}, 
    'Etiopía/Plaza de la Transparencia': {'Centro Médico': 2, 'Eugenia': 2},
    'Eugenia': {'Etiopía/Plaza de la Transparencia': 2, 'División del Norte': 2},
    'División del Norte': {'Eugenia': 2, 'Zapata': 2},
    'Zapata': {'División del Norte': 2, 'Coyoacán': 2, 'Parque de los Venados': 2, 'Hospital 20 de Noviembre': 2}, 
    'Coyoacán': {'Zapata': 2, 'Viveros/Derechos Humanos': 2},
    'Viveros/Derechos Humanos': {'Coyoacán': 2, 'Miguel Ángel de Quevedo': 2},
    'Miguel Ángel de Quevedo': {'Viveros/Derechos Humanos': 2, 'Copilco': 2},
    'Copilco': {'Miguel Ángel de Quevedo': 2, 'Universidad': 3},
    'Universidad': {'Copilco': 3},
    
    # --- LÍNEA 4 ---
    'Martín Carrera': {'Talismán': 2, 'La Villa-Basílica': 3}, 
    'Talismán': {'Martín Carrera': 2, 'Bondojito': 2},
    'Bondojito': {'Talismán': 2, 'Consulado': 2},
    'Consulado': {'Bondojito': 2, 'Canal del Norte': 2, 'Valle Gómez': 2, 'Eduardo Molina': 2}, 
    'Canal del Norte': {'Consulado': 2, 'Morelos': 2},
    'Morelos': {'Canal del Norte': 2, 'Candelaria': 2, 'San Lázaro': 2, 'Tepito': 2}, 
    'Candelaria': {'Morelos': 2, 'Fray Servando': 2, 'San Lázaro': 2, 'Merced': 2}, 
    'Fray Servando': {'Candelaria': 2, 'Jamaica': 2},
    'Jamaica': {'Fray Servando': 2, 'Santa Anita': 2, 'Mixiuhca': 2, 'Chabacano': 2}, 
    'Santa Anita': {'Jamaica': 2, 'Viga': 2, 'Coyuya': 2},
    
    # --- LÍNEA 5 ---
    'Politécnico': {'Instituto del Petróleo': 3},
    'Instituto del Petróleo': {'Politécnico': 3, 'Autobuses del Norte': 2, 'Vallejo': 2, 'Lindavista': 2}, 
    'Autobuses del Norte': {'Instituto del Petróleo': 2, 'La Raza': 2},
    'Misterios': {'La Raza': 2, 'Valle Gómez': 2},
    'Valle Gómez': {'Misterios': 2, 'Consulado': 2},
    'Eduardo Molina': {'Consulado': 2, 'Aragón': 2},
    'Aragón': {'Eduardo Molina': 2, 'Oceanía': 2},
    'Oceanía': {'Aragón': 2, 'Terminal Aérea': 2, 'Deportivo Oceanía': 2, 'Romero Rubio': 2}, 
    'Terminal Aérea': {'Oceanía': 2, 'Hangares': 2},
    'Hangares': {'Terminal Aérea': 2, 'Pantitlán': 2},
    'Pantitlán': {'Hangares': 2, 'Zaragoza': 3, 'Puebla': 2, 'Agrícola Oriental': 2},

    # --- LÍNEA 6 ---
    'El Rosario': {'Tezozómoc': 2, 'Aquiles Serdán': 2},
    'Tezozómoc': {'El Rosario': 2, 'UAM Azcapotzalco': 2},
    'UAM Azcapotzalco': {'Tezozómoc': 2, 'Ferrería/Arena Ciudad de México': 2},
    'Ferrería/Arena Ciudad de México': {'UAM Azcapotzalco': 2, 'Norte 45': 2},
    'Norte 45': {'Ferrería/Arena Ciudad de México': 2, 'Vallejo': 2},
    'Vallejo': {'Norte 45': 2, 'Instituto del Petróleo': 2},
    'Lindavista': {'Instituto del Petróleo': 2, 'Deportivo 18 de Marzo': 2},
    'La Villa-Basílica': {'Deportivo 18 de Marzo': 2, 'Martín Carrera': 2},

    # --- LÍNEA 7 ---
    'Aquiles Serdán': {'El Rosario': 2, 'Camarones': 2},
    'Camarones': {'Aquiles Serdán': 2, 'Refinería': 2},
    'Refinería': {'Camarones': 2, 'Tacuba': 2},
    'San Joaquín': {'Tacuba': 2, 'Polanco': 2},
    'Polanco': {'San Joaquín': 2, 'Auditorio': 2},
    'Auditorio': {'Polanco': 2, 'Constituyentes': 2},
    'Constituyentes': {'Auditorio': 2, 'Tacubaya': 2},
    'San Pedro de los Pinos': {'Tacubaya': 2, 'San Antonio': 2},
    'San Antonio': {'San Pedro de los Pinos': 2, 'Mixcoac': 2},
    'Mixcoac': {'San Antonio': 2, 'Barranca del Muerto': 3, 'Insurgentes Sur': 2}, 
    'Barranca del Muerto': {'Mixcoac': 3},

    # --- LÍNEA 8 ---
    'Garibaldi': {'Bellas Artes': 2,'Guerrero': 2, 'Lagunilla': 2}, 
    'San Juan de Letrán': {'Bellas Artes': 2, 'Salto del Agua': 2},
    'Doctores': {'Salto del Agua': 2, 'Obrera': 2},
    'Obrera': {'Doctores': 2, 'Chabacano': 2},
    'Viga': {'Chabacano': 2, 'Santa Anita': 2},
    'Coyuya': {'Santa Anita': 2, 'Iztacalco': 2},
    'Iztacalco': {'Coyuya': 2, 'Apatlaco': 2},
    'Apatlaco': {'Iztacalco': 2, 'Aculco': 2},
    'Aculco': {'Apatlaco': 2, 'Escuadrón 201': 2},
    'Escuadrón 201': {'Aculco': 2, 'Atlalilco': 2},
    'Atlalilco': {'Escuadrón 201': 2, 'Iztapalapa': 2, 'Mexicaltzingo': 2, 'Culhuacán': 2},
    'Iztapalapa': {'Atlalilco': 2, 'Cerro de la Estrella': 2},
    'Cerro de la Estrella': {'Iztapalapa': 2, 'UAM-I': 2},
    'UAM-I': {'Cerro de la Estrella': 2, 'Constitución de 1917': 3},
    'Constitución de 1917': {'UAM-I': 3},

    # --- LÍNEA 9 ---
    'Patriotismo': {'Tacubaya': 2, 'Chilpancingo': 2},
    'Chilpancingo': {'Patriotismo': 2, 'Centro Médico': 2},
    'Lázaro Cárdenas': {'Centro Médico': 2, 'Chabacano': 2}, 
    'Mixiuhca': {'Jamaica': 2, 'Velódromo': 2},
    'Velódromo': {'Mixiuhca': 2, 'Ciudad Deportiva': 2},
    'Ciudad Deportiva': {'Velódromo': 2, 'Puebla': 2},
    'Puebla': {'Ciudad Deportiva': 2, 'Pantitlán': 2},

    # --- LÍNEA A ---
    'Agrícola Oriental': {'Pantitlán': 2, 'Canal de San Juan': 2},
    'Canal de San Juan': {'Agrícola Oriental': 2, 'Tepalcates': 2},
    'Tepalcates': {'Canal de San Juan': 2, 'Guelatao': 2},
    'Guelatao': {'Tepalcates': 2, 'Peñón Viejo': 2},
    'Peñón Viejo': {'Guelatao': 2, 'Acatitla': 2},
    'Acatitla': {'Peñón Viejo': 2, 'Santa Marta': 2},
    'Santa Marta': {'Acatitla': 2, 'Los Reyes': 2},
    'Los Reyes': {'Santa Marta': 2, 'La Paz': 3},
    'La Paz': {'Los Reyes': 3},

    # --- LÍNEA B ---
    'Buenavista': {'Guerrero': 3}, 
    'Lagunilla': {'Garibaldi': 2, 'Tepito': 2},
    'Tepito': {'Lagunilla': 2, 'Morelos': 2},
    'Ricardo Flores Magón': {'San Lázaro': 2, 'Romero Rubio': 2},
    'Romero Rubio': {'Ricardo Flores Magón': 2, 'Oceanía': 2},
    'Deportivo Oceanía': {'Oceanía': 2, 'Bosque de Aragón': 2},
    'Bosque de Aragón': {'Deportivo Oceanía': 2, 'Villa de Aragón': 2},
    'Villa de Aragón': {'Bosque de Aragón': 2, 'Nezahualcóyotl': 2},
    'Nezahualcóyotl': {'Villa de Aragón': 2, 'Impulsora': 2},
    'Impulsora': {'Nezahualcóyotl': 2, 'Río de los Remedios': 2},
    'Río de los Remedios': {'Impulsora': 2, 'Múzquiz': 2},
    'Múzquiz': {'Río de los Remedios': 2, 'Ecatepec': 2},
    'Ecatepec': {'Múzquiz': 2, 'Olímpica': 2},
    'Olímpica': {'Ecatepec': 2, 'Plaza Aragón': 2},
    'Plaza Aragón': {'Olímpica': 2, 'Ciudad Azteca': 3},
    'Ciudad Azteca': {'Plaza Aragón': 3},

    # --- LÍNEA 12 ---
    'Insurgentes Sur': {'Mixcoac': 2, 'Hospital 20 de Noviembre': 2},
    'Hospital 20 de Noviembre': {'Insurgentes Sur': 2, 'Zapata': 2},
    'Parque de los Venados': {'Zapata': 2, 'Eje Central': 2},
    'Eje Central': {'Parque de los Venados': 2, 'Ermita': 2},
    'Mexicaltzingo': {'Ermita': 2, 'Atlalilco': 2},
    'Culhuacán': {'Atlalilco': 2, 'Tomatlán': 2},
    'Tomatlán': {'Culhuacán': 2, 'Lomas Estrella': 2},
    'Lomas Estrella': {'Tomatlán': 2, 'Calle 11': 2},
    'Calle 11': {'Lomas Estrella': 2, 'Periférico Oriente': 2},
    'Periférico Oriente': {'Calle 11': 2, 'Tezonco': 2},
    'Tezonco': {'Periférico Oriente': 2, 'Olivos': 2},
    'Olivos': {'Tezonco': 2, 'Nopalera': 2},
    'Nopalera': {'Olivos': 2, 'Zapotitlán': 2},
    'Zapotitlán': {'Nopalera': 2, 'Tlaltenco': 2},
    'Tlaltenco': {'Zapotitlán': 2, 'Tláhuac': 3},
    'Tláhuac': {'Tlaltenco': 3}
}

# %%
class Node:
    def __init__(self, state, parent = None, action = None, path_cost = 0):
        self.state = state
        self.parent = parent
        self.action = action
        self.path_cost = path_cost

    def path(self):
        lista_path = []
        node = self
        while node:
            lista_path.append(node.state)
            node = node.parent
        return lista_path[::-1]

    def expand(self, problem):
        lista = []
        for action in problem.actions(self.state):
            lista.append(self.child_node(problem, action))
        return lista

    def child_node(self, problem, action):
        next_state = problem.result(self.state, action)
        step_cost = problem.action_cost(self.state, action, next_state)
        return Node(next_state, self, action, self.path_cost + step_cost)

# %%
def depth_first_graph_search(problem):
    start_node = Node(problem.initial)
    if problem.is_goal(start_node.state):
        return start_node
    frontier = [start_node]
    explored = set()

    while frontier:
        node = frontier.pop()
        explored.add(node.state)

        if problem.is_goal(node.state):
            return node

        for child in node.expand(problem):
            if child.state not in explored:
                frontier.append(child)
    return None

# %%
from collections import deque

def breadth_first_graph_search(problem):
    start_node = Node(problem.initial)
    if problem.is_goal(start_node.state):
        return start_node
    frontier = deque([start_node])
    explored = set()

    while frontier:
        node = frontier.popleft()
        explored.add(node.state)

        if problem.is_goal(node.state):
            return node

        for child in node.expand(problem):
            if child.state not in explored:
                frontier.append(child)
    return None

# %%
problem = GraphProblem("Cuatro Caminos", "Pantitlán", metro_cdmx)
node = depth_first_graph_search(problem)
node.path()
# Out:
# ['Cuatro Caminos',
#  'Panteones',
#  'Tacuba',
#  'Refinería',
#  'Camarones',
#  'Aquiles Serdán',
#  'El Rosario',
#  'Tezozómoc',
#  'UAM Azcapotzalco',
#  'Ferrería/Arena Ciudad de México',
#  'Norte 45',
#  'Vallejo',
#  'Instituto del Petróleo',
#  'Lindavista',
#  'Deportivo 18 de Marzo',
#  'La Villa-Basílica',
#  'Martín Carrera',
#  'Talismán',
#  'Bondojito',
#  'Consulado',
#  'Eduardo Molina',
#  'Aragón',
#  'Oceanía',
#  'Romero Rubio',
#  'Ricardo Flores Magón',
#  'San Lázaro',
#  'Morelos',
#  'Tepito',
#  'Lagunilla',
#  'Garibaldi',
#  'Guerrero',
#  'Hidalgo',
#  'Juárez',
#  'Balderas',
#  'Niños Héroes',
#  'Hospital General',
#  'Centro Médico',
#  'Lázaro Cárdenas',
#  'Chabacano',
#  'Jamaica',
#  'Mixiuhca',
#  'Velódromo',
#  'Ciudad Deportiva',
#  'Puebla',
#  'Pantitlán']

# %%
problem = GraphProblem("Politécnico", "Taxqueña", metro_cdmx)
node = depth_first_graph_search(problem)
node.path()
# Out:
# ['Politécnico',
#  'Instituto del Petróleo',
#  'Lindavista',
#  'Deportivo 18 de Marzo',
#  'La Villa-Basílica',
#  'Martín Carrera',
#  'Talismán',
#  'Bondojito',
#  'Consulado',
#  'Eduardo Molina',
#  'Aragón',
#  'Oceanía',
#  'Romero Rubio',
#  'Ricardo Flores Magón',
#  'San Lázaro',
#  'Morelos',
#  'Tepito',
#  'Lagunilla',
#  'Garibaldi',
#  'Guerrero',
#  'Hidalgo',
#  'Juárez',
#  'Balderas',
#  'Niños Héroes',
#  'Hospital General',
#  'Centro Médico',
#  'Lázaro Cárdenas',
#  'Chabacano',
#  'Jamaica',
#  'Santa Anita',
#  'Coyuya',
#  'Iztacalco',
#  'Apatlaco',
#  'Aculco',
#  'Escuadrón 201',
#  'Atlalilco',
#  'Mexicaltzingo',
#  'Ermita',
#  'General Anaya',
#  'Taxqueña']

# %%
problem = GraphProblem("Zapata", "Oceanía", metro_cdmx)
node = depth_first_graph_search(problem)
node.path()
# Out:
# ['Zapata',
#  'Hospital 20 de Noviembre',
#  'Insurgentes Sur',
#  'Mixcoac',
#  'San Antonio',
#  'San Pedro de los Pinos',
#  'Tacubaya',
#  'Patriotismo',
#  'Chilpancingo',
#  'Centro Médico',
#  'Lázaro Cárdenas',
#  'Chabacano',
#  'Jamaica',
#  'Mixiuhca',
#  'Velódromo',
#  'Ciudad Deportiva',
#  'Puebla',
#  'Pantitlán',
#  'Zaragoza',
#  'Gómez Farías',
#  'Boulevard Puerto Aéreo',
#  'Balbuena',
#  'Moctezuma',
#  'San Lázaro',
#  'Morelos',
#  'Tepito',
#  'Lagunilla',
#  'Garibaldi',
#  'Guerrero',
#  'Hidalgo',
#  'Revolución',
#  'San Cosme',
#  'Normal',
#  'Colegio Militar',
#  'Popotla',
#  'Cuitláhuac',
#  'Tacuba',
#  'Refinería',
#  'Camarones',
#  'Aquiles Serdán',
#  'El Rosario',
#  'Tezozómoc',
#  'UAM Azcapotzalco',
#  'Ferrería/Arena Ciudad de México',
#  'Norte 45',
#  'Vallejo',
#  'Instituto del Petróleo',
#  'Lindavista',
#  'Deportivo 18 de Marzo',
#  'La Villa-Basílica',
#  'Martín Carrera',
#  'Talismán',
#  'Bondojito',
#  'Consulado',
# ...

# %%
problem = GraphProblem("Cuatro Caminos", "Pantitlán", metro_cdmx)
node = breadth_first_graph_search(problem)
node.path()
# Out:
# ['Cuatro Caminos',
#  'Panteones',
#  'Tacuba',
#  'San Joaquín',
#  'Polanco',
#  'Auditorio',
#  'Constituyentes',
#  'Tacubaya',
#  'Patriotismo',
#  'Chilpancingo',
#  'Centro Médico',
#  'Lázaro Cárdenas',
#  'Chabacano',
#  'Jamaica',
#  'Mixiuhca',
#  'Velódromo',
#  'Ciudad Deportiva',
#  'Puebla',
#  'Pantitlán']

# %%
problem = GraphProblem("Politécnico", "Taxqueña", metro_cdmx)
node = breadth_first_graph_search(problem)
node.path()
# Out:
# ['Politécnico',
#  'Instituto del Petróleo',
#  'Autobuses del Norte',
#  'La Raza',
#  'Tlatelolco',
#  'Guerrero',
#  'Hidalgo',
#  'Bellas Artes',
#  'Allende',
#  'Zócalo/Tenochtitlan',
#  'Pino Suárez',
#  'San Antonio Abad',
#  'Chabacano',
#  'Viaducto',
#  'Xola',
#  'Villa de Cortés',
#  'Nativitas',
#  'Portales',
#  'General Anaya',
#  'Taxqueña']

# %%
problem = GraphProblem("Zapata", "Oceanía", metro_cdmx)
node = breadth_first_graph_search(problem)
node.path()
# Out:
# ['Zapata',
#  'División del Norte',
#  'Eugenia',
#  'Etiopía/Plaza de la Transparencia',
#  'Centro Médico',
#  'Lázaro Cárdenas',
#  'Chabacano',
#  'Jamaica',
#  'Fray Servando',
#  'Candelaria',
#  'San Lázaro',
#  'Ricardo Flores Magón',
#  'Romero Rubio',
#  'Oceanía']
